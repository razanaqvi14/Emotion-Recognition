# %%
import tensorflow as tf
import os
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
model = tf.keras.models.load_model("Model/happysadclassificationmodel.keras")

# %%
for image in os.listdir("Test Images"):
    image_as_an_array = cv2.imread(os.path.join("Test Images", image))
    resized_image = tf.image.resize(image_as_an_array, (256, 256))
    prediction = model.predict(np.expand_dims(resized_image / 255, 0))
    plt.imshow(cv2.cvtColor(image_as_an_array, cv2.COLOR_BGR2RGB))
    if prediction > 0.5:
        plt.title("The person is predicted to be sad")
    else:
        plt.title("The person is predicted to be happy")
    plt.axis("off")
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
8 * 32
# Out:
# 256
